# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/dirk/Downloads/Somerville_Happiness_Survey_responses_-_2011__2013__2015.csv')

# %%
df.describe()
# Out:
#        Combined_ID         Year  \
# count  6545.000000  6545.000000
# mean   3273.000000  2011.172040
# std    1889.523088     0.735317
# min       1.000000  2011.000000
# 25%    1637.000000  2011.000000
# 50%    3273.000000  2011.000000
# 75%    4909.000000  2011.000000
# max    6545.000000  2015.000000
#
#        How.satisfied.are.you.with.your.neighborhood.  \
# count                                     378.000000
# mean                                        7.828042
# std                                         1.970823
# min                                         1.000000
# 25%                                         7.000000
# 50%                                         8.000000
# 75%                                         9.000000
# max                                        10.000000
#
#        How.proud.are.you.to.be.a.Somerville.resident._2015  \
# count                                         182.000000
# mean                                            8.192308
# ...

# %%
df.isnull().sum()
# Out:
# Combined_ID                                                                                           0
# Year                                                                                                  0
# How.happy.do.you.feel.right.now.                                                                      1
# How.satisfied.are.you.with.your.life.in.general.                                                      2
# How.satisfied.are.you.with.Somerville.as.a.place.to.live.                                             0
# In.general..how.similar.are.you.to.other.people.you.know._2011                                      378
# When.making.decisions..are.you.more.likely.to.seek.advice.or.decide.for.yourself._2011.             378
# How.satisfied.are.you.with.your.neighborhood.                                                      6167
# How.proud.are.you.to.be.a.Somerville.resident._2015                                                6363
# ...

# %%
df.size
# Out:
# 281435

# %%
df.shape
# Out:
# (6545, 43)

# %%
df.dropna().shape
# Out:
# (0, 43)
